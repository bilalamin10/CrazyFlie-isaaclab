# %%
from isaaclab.utils import math as math_utils
import torch

x = torch.tensor([0.707, 0, 0, 0.707])
y = torch.tensor([0.0,0.0,1.0])
math_utils.quat_apply(x, y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from isaaclab.utils import math as math_utils
#       2 import torch
#       4 x = torch.tensor([0.707, 0, 0, 0.707])
#
# File ~/IsaacLab/source/isaaclab/isaaclab/utils/math.py:17
#      14 import torch.nn.functional
#      15 from typing import Literal
# ---> 17 import omni.log
#      19 """
#      20 General
#      21 """
#      24 @torch.jit.script
#      25 def scale_transform(x: torch.Tensor, lower: torch.Tensor, upper: torch.Tensor) -> torch.Tensor:
#
# ModuleNotFoundError: No module named 'omni.log'
